# %%
def calculate_discounted_price(price):
    if price >= 5000: 
        return price * 0.75  
    elif price >= 2000: 
        return price * 0.50 
    elif price >= 1000: 
        return price * 0.25  
    else: 
        return price        

if __name__ == '__main__':
    yesorno = "Y" 
    
    while yesorno == "Y":
        try:
            price = float(input("Enter price: "))
            if price >= 0:
                final_price = calculate_discounted_price(price)
                print(f"Original Price: {price:.2f}")
                print(f"Final Price: {final_price:.2f}")
            else:
                print("Price cannot be negative.")
        except ValueError:
            print("Please enter a valid number.")
            
        yesorno = input("\nCalculate another? (Y or N): ")
# Out:
# Original Price: 4500.00
# Final Price: 2250.00
# Original Price: 3400.00
# Final Price: 1700.00

# %%
def factorial(a):
    fac = 1 
    while a > 0:
        fac *= a
        a -= 1
    return fac
def circle(r):
    return 3.14*r*r
def rectangle(l,b):
    return l*b
if __name__ == '__main__':
    yesorno = "Y" 
    while yesorno.upper() == "Y":
        try:
            
            a = int(input("Number: "))
            
            if a < 0:
                print("Please enter a positive integer or zero.")
            else:
                result = factorial(a)
                print(f"The factorial of {a} is: {result}")
                area=circle(a)
                print(f"The area of {a} is:{area}")
                
        except ValueError:
            print("Invalid input. Please enter a valid whole number.")
            
        yesorno = input("Do you want to calculate another? (Y/N): ")
# Out:
# The factorial of 6 is: 720
# The area of 6 is:113.03999999999999
# The factorial of 4 is: 24
# The area of 4 is:50.24

# %%
student_list = [
    {"name": "apple", "prn": "123"},
    {"name": "orange", "prn": "456"}
]

def presentornot(search_value, students_data):

    for student in students_data:
        if student.get("name") == search_value or student.get("prn") == search_value:
            return True
            
    return False


print(presentornot("apple", student_list)) 

print(presentornot("456", student_list))   

print(presentornot("grape", student_list))
# Out:
# True
# True
# False

# %%
lst=[-1,1,2,3,4,5]
res= list(map(lambda x: (x+x,x*x),lst))
print(res)
newl = list(filter(lambda x: x[0] > 0, res))
print(newl)
# Out:
# [(-2, 1), (2, 1), (4, 4), (6, 9), (8, 16), (10, 25)]
# [(2, 1), (4, 4), (6, 9), (8, 16), (10, 25)]

# %% [markdown]
# positional and keyword are two type of parameters and their combination

# %%
def example(x, y, z=30):
    return x, y, z
#positional arguementa
print(example(10, 20))

# Keyword arguments
print(example(x=10, y=20, z=380))

# Mixed positional + keyword arguments
print(example(10, y=720, z=30))
# Out:
# (10, 20, 30)
# (10, 20, 380)
# (10, 720, 30)

# %%
if __name__ == '__main__':
        try:
            
            a = int(input("Number: "))
            b = int(input("Number: "))
            print(a/b)
        except TypeError:
            print("unsuported op")
        except ZeroDivisionError:
            print("b should not be equal to 0")
                
        except ValueError:
            print("Invalid input. Please enter a valid whole number.")
# Out:
# Invalid input. Please enter a valid whole number.

# %%
num = [2,3,5,6]
if len(num) > 3:
    print("length is greater than 3")
# Out:
# length is greater than 3

# %%
try:
    fac + "abc"
except TypeError as e:
    print("TypeError raised:", e)

try:
    fac / a
except ZeroDivisionError as e:
    print("ZeroDivisionError raised:", e)

try:
    int("abc")
except ValueError as e:
    print("ValueError raised:", e)

# %%
try:
    fac + "abc"
except TypeError as e:
    print("TypeError raised:", e)

try:
    fac / a
except ZeroDivisionError as e:
    print("ZeroDivisionError raised:", e)

try:
    int("abc")
except ValueError as e:
    print("ValueError raised:", e)
# Out:
# TypeError raised: unsupported operand type(s) for +: 'int' and 'str'
# ZeroDivisionError raised: division by zero
# ValueError raised: invalid literal for int() with base 10: 'abc'

# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.12.4 (tags/v3.12.4:8e8a4ba, Jun  6 2024, 19:30:16) [MSC v.1940 64 bit (AMD64)]
# c:\Users\Asus\AppData\Local\Programs\Python\Python312\python.exe

# %%
import sys
lists2 = [1,3,2]
for entry in lists2:
    try:
        print("The entry is ",entry)
        r = 1/int(entry)
        break
    except:
        print("error",sys.exc_info[0],"occured")
        print("Next entry:")
        print()
print("The reciprocal of", entry, "is", r)
# Out:
# The entry is  1
# The reciprocal of 1 is 1.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
series1= pd.Series({'a':20,'b':40})
series1
# Out:
# a    20
# b    40
# dtype: int64

# %%
series2= pd.Series([40,60,60,80])
series2
# Out:
# 0    40
# 1    60
# 2    60
# 3    80
# dtype: int64

# %%
series3 = pd.Series(5, index =['a','b','c'])
series3
# Out:
# a    5
# b    5
# c    5
# dtype: int64

# %%
series2.dtype
# Out:
# dtype('int64')

# %%
series2.size
# Out:
# 4

# %%
ser = np.array(['a','d','g','h'])
series4=pd.Series(ser)
series4
# Out:
# 0    a
# 1    d
# 2    g
# 3    h
# dtype: str

# %%
series4[1:4]
# Out:
# 1    d
# 2    g
# 3    h
# dtype: str

# %%
df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'age': [25, 30, 35, 28],
    'city': ['New York', 'London', 'Paris', 'Tokyo']
})
df = pd.DataFrame(df)
df
# Out:
#       name  age      city
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris
# 3    David   28     Tokyo

# %%
data = np.arange(12).reshape(3, 4)

df_default_index = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])
print("DataFrame with default index:")
print(df_default_index)

df_custom_index = pd.DataFrame(
    data,
    index=['row1', 'row2', 'row3'],
    columns=['A', 'B', 'C', 'D']
)
print("\nDataFrame with custom index:")
print(df_custom_index)

reshaped = df_default_index.values.reshape(4, 3)
print("\nReshaped array from DataFrame values:")
print(reshaped)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = np.arange(12).reshape(3, 4)
#       3 df_default_index = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])
#       4 print("DataFrame with default index:")
#
# NameError: name 'np' is not defined
